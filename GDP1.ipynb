# %%
import pandas as pd

# %%
DF1=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\DataI.csv')

# %%
#DF1.drop([5,6,7,8,9,10],axis=0,inplace=True)

# %%
DF1
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
DF1.drop([5,10],axis=0,inplace=True) # removing rows for year 2016-17

# %%
DF1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
DF2=DF1.iloc[6:10,:-1]   # selecting rows '(% Growth over previous year)' over the duration 2013-14, 2014-15 and 2015-16 
                         # for all States

# %%
DF2
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana     ...      \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45     ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18     ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91     ...
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 7       13.51      12.63    18.14          14.73        13.64           NaN
# 8       12.51      13.05    15.92          10.51         8.12           NaN
# 9       10.99      12.61      NaN          10.58        13.65           NaN
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry
# ...

# %%
DF2.set_index('Duration',inplace=True)

# %%
DF2
# Out:
#                      Items  Description  Andhra Pradesh   Arunachal Pradesh  \
# Duration
# 2013-14   (% Growth over previous year)            12.85              16.38
# 2014-15   (% Growth over previous year)            13.40              14.79
# 2015-16   (% Growth over previous year)            15.85              12.07
#
#           Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  \
# Duration
# 2013-14   13.31  12.30         16.44  -5.77    11.47    15.45
# 2014-15   11.45  17.92         13.69  13.12    10.82     9.18
# 2015-16   13.19  10.59         10.98  10.75    11.09    10.91
#
#           Himachal Pradesh     ...      Tamil Nadu  Telangana  Tripura  \
# Duration                       ...
# 2013-14              14.42     ...           13.51      12.63    18.14
# 2014-15              10.14     ...           12.51      13.05    15.92
# 2015-16                NaN     ...           10.99      12.61      NaN
#
# ...

# %%
DF2.drop("Items  Description",axis=1,inplace=True)

# %%
DF2
# Out:
#           Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# Duration
# 2013-14             12.85              16.38  13.31  12.30         16.44
# 2014-15             13.40              14.79  11.45  17.92         13.69
# 2015-16             15.85              12.07  13.19  10.59         10.98
#
#             Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  \
# Duration
# 2013-14   -5.77    11.47    15.45             14.42            10.09
# 2014-15   13.12    10.82     9.18             10.14             4.70
# 2015-16   10.75    11.09    10.91               NaN            17.91
#
#              ...      Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# Duration     ...
# 2013-14      ...           13.51      12.63    18.14          14.73
# 2014-15      ...           12.51      13.05    15.92          10.51
# 2015-16      ...           10.99      12.61      NaN          10.58
#
#           Uttarakhand  West Bengal1  Andaman & Nicobar Islands  Chandigarh  \
# ...

# %%
DF3=DF2.mean(axis=0)

# %%
DF3
# Out:
# Andhra Pradesh               14.033333
# Arunachal Pradesh            14.413333
# Assam                        12.650000
# Bihar                        13.603333
# Chhattisgarh                 13.703333
# Goa                           6.033333
# Gujarat                      11.126667
# Haryana                      11.846667
# Himachal Pradesh             12.280000
# Jammu & Kashmir              10.900000
# Jharkhand                    11.500000
# Karnataka                    14.120000
# Kerala                       12.583333
# Madhya Pradesh               12.626667
# Maharashtra                  11.260000
# Manipur                      14.610000
# Meghalaya                     6.953333
# Mizoram                      17.700000
# Nagaland                     16.415000
# Odisha                        9.836667
# Punjab                       11.185000
# Rajasthan                    11.320000
# Sikkim                       10.486667
# Tamil Nadu                   12.336667
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt=DF3.sort_values().plot(kind='bar',grid=True,title='Average % Growth over previous year for all States',figsize=(10,5))

# %%
DF4=DF1.iloc[6:10,:]

# %%
DF4
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana      ...        \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45      ...
# 8  11.45  17.92         13.69  13.12    10.82     9.18      ...
# 9  13.19  10.59         10.98  10.75    11.09    10.91      ...
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 7      12.63    18.14          14.73        13.64           NaN
# 8      13.05    15.92          10.51         8.12           NaN
# 9      12.61      NaN          10.58        13.65           NaN
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
DF3['Bihar']
# Out:
# 13.603333333333333

# %%
DF4['All_India GDP'].mean() # when compared to national average, my home town is growing faster :)
# Out:
# 11.203333333333333

# %%
DF1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
DF5=DF1.iloc[4:5,1:-1]  # selecting data for year 2015-16

# %%
DF5=DF5.dropna(axis='columns')

# %%
DF5.set_index('Duration',inplace=True)

# %%
DF5.sort_values(by='2015-16',ascending=False,inplace=True)
#DF5=DF5.transpose()

# %%
DF5
# Out:
# Duration             2015-16
# Tamil Nadu         1212668.0
# Uttar Pradesh      1153795.0
# Karnataka          1027068.0
# Gujarat             994316.0
# Andhra Pradesh      609934.0
# Kerala              588337.0
# Telangana           575631.0
# Delhi               551963.0
# Madhya Pradesh      543975.0
# Haryana             485184.0
# Bihar               413503.0
# Odisha              341887.0
# Chhattisgarh        260776.0
# Jharkhand           241955.0
# Assam               224234.0
# Uttarakhand         184091.0
# Jammu & Kashmir     118387.0
# Goa                  45002.0
# Chandigarh           30304.0
# Meghalaya            26745.0
# Puducherry           26533.0
# Arunachal Pradesh    18784.0
# Sikkim               16637.0

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(20,10)

# %%
DF5.plot(kind='bar',sort_columns =True,title='Total GDP of the states for the year 2015-16')

# %%
#DF5.set_index('Duration',inplace=True)
DF5
# Out:
# Duration             2015-16
# Tamil Nadu         1212668.0
# Uttar Pradesh      1153795.0
# Karnataka          1027068.0
# Gujarat             994316.0
# Andhra Pradesh      609934.0
# Kerala              588337.0
# Telangana           575631.0
# Delhi               551963.0
# Madhya Pradesh      543975.0
# Haryana             485184.0
# Bihar               413503.0
# Odisha              341887.0
# Chhattisgarh        260776.0
# Jharkhand           241955.0
# Assam               224234.0
# Uttarakhand         184091.0
# Jammu & Kashmir     118387.0
# Goa                  45002.0
# Chandigarh           30304.0
# Meghalaya            26745.0
# Puducherry           26533.0
# Arunachal Pradesh    18784.0
# Sikkim               16637.0

# %%
#DF5.sort_values(by = '2015-16', ascending = False)
Top5 = DF5.iloc[:5, ]
Bottom5=DF5.iloc[-5:,:]

# %%
Top5
# Out:
# Duration           2015-16
# Tamil Nadu       1212668.0
# Uttar Pradesh    1153795.0
# Karnataka        1027068.0
# Gujarat           994316.0
# Andhra Pradesh    609934.0

# %%
Bottom5
# Out:
# Duration           2015-16
# Chandigarh         30304.0
# Meghalaya          26745.0
# Puducherry         26533.0
# Arunachal Pradesh  18784.0
# Sikkim             16637.0
