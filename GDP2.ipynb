# %%
import pandas as pd

# %%
DF_Andhra=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv',usecols=['S.No.','Item','2014-15'])
DF_Arunachal=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Assam=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Assam-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Bihar=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Bihar-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Chhattisgarh=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Chhattisgarh-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Goa=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Goa-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Gujarat=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Gujarat-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Haryana=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Haryana-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_HP=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Jharkhand=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Jharkhand-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Karnataka=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Karnataka-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Kerala=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Kerala-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_MP=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Maharashtra=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Maharashtra-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Manipur=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Manipur-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'],encoding='unicode_escape')
DF_Meghalaya=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Meghalaya-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Mizoram=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Mizoram-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Nagaland=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Nagaland-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Odisha=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Odisha-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Punjab=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Punjab-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Rajasthan=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Rajasthan-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_Sikkim=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Sikkim-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_TN=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Tamil_Nadu-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Telangana=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Telangana-GSVA_cur_2016-17.csv',usecols=['Item','2014-15'])
DF_Tripura=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Tripura-GSVA_cur_2014-15.csv',usecols=['Item','2014-15'])
DF_UP=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])
DF_Uttarakhand=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2\NAD-Uttarakhand-GSVA_cur_2015-16.csv',usecols=['Item','2014-15'])

# %%
df1 = pd.merge(DF_Andhra, DF_Arunachal, how='inner', on='Item')

# %%
df1.rename(columns={'2014-15_x': '2014-15_Andhra', '2014-15_y': '2014-15_Arunachal'}, inplace=True)

# %%
df1
# Out:
#     S.No.                                               Item  2014-15_Andhra  \
# 0       1                  Agriculture, forestry and fishing        14819416
# 1     1.1                                              Crops         7893514
# 2     1.2                                          Livestock         4309078
# 3     1.3                               Forestry and logging          346160
# 4     1.4                            Fishing and aquaculture         2270664
# 5       2                               Mining and quarrying         1484300
# 6   Total                                            Primary        16303716
# 7       3                                      Manufacturing         4672266
# 8       4  Electricity, gas, water supply & other utility...         1151729
# 9       5                                       Construction         4664889
# 10  Total                                          Secondary        10488884
# ...

# %%
df2 = pd.merge(df1,DF_Assam,how='inner',on='Item')
df2.rename(columns={'2014-15': '2014-15_Assam'}, inplace=True)
df2
# Out:
#     S.No.                                               Item  2014-15_Andhra  \
# 0       1                  Agriculture, forestry and fishing        14819416
# 1     1.1                                              Crops         7893514
# 2     1.2                                          Livestock         4309078
# 3     1.3                               Forestry and logging          346160
# 4     1.4                            Fishing and aquaculture         2270664
# 5       2                               Mining and quarrying         1484300
# 6   Total                                            Primary        16303716
# 7       3                                      Manufacturing         4672266
# 8       4  Electricity, gas, water supply & other utility...         1151729
# 9       5                                       Construction         4664889
# 10  Total                                          Secondary        10488884
# ...

# %%
df3= pd.merge(df2,DF_Bihar,how='inner',on='Item')
df3.rename(columns={'2014-15': '2014-15_Bihar'}, inplace=True)
df3
# Out:
#     S.No.                                               Item  2014-15_Andhra  \
# 0       1                  Agriculture, forestry and fishing        14819416
# 1     1.1                                              Crops         7893514
# 2     1.2                                          Livestock         4309078
# 3     1.3                               Forestry and logging          346160
# 4     1.4                            Fishing and aquaculture         2270664
# 5       2                               Mining and quarrying         1484300
# 6   Total                                            Primary        16303716
# 7       3                                      Manufacturing         4672266
# 8       4  Electricity, gas, water supply & other utility...         1151729
# 9       5                                       Construction         4664889
# 10  Total                                          Secondary        10488884
# ...

# %%
df4= pd.merge(df3,DF_Chhattisgarh,how='inner',on='Item')
df4.rename(columns={'2014-15': '2014-15_Chhattisgarh'}, inplace=True)
df4

df5= pd.merge(df4,DF_Goa,how='inner',on='Item')
df5.rename(columns={'2014-15': '2014-15_Goa'}, inplace=True)

df6= pd.merge(df5,DF_Gujarat,how='inner',on='Item')
df6.rename(columns={'2014-15': '2014-15_Gujarat'}, inplace=True)

df7= pd.merge(df6,DF_Haryana,how='inner',on='Item')
df7.rename(columns={'2014-15': '2014-15_Haryana'}, inplace=True)

df8= pd.merge(df7,DF_HP,how='inner',on='Item')
df8.rename(columns={'2014-15': '2014-15_HP'}, inplace=True)

df9= pd.merge(df8,DF_Jharkhand,how='inner',on='Item')
df9.rename(columns={'2014-15': '2014-15_Jharkhand'}, inplace=True)

df10= pd.merge(df9,DF_Karnataka,how='inner',on='Item')
df10.rename(columns={'2014-15': '2014-15_Karnataka'}, inplace=True)

df11= pd.merge(df10,DF_Kerala,how='inner',on='Item')
df11.rename(columns={'2014-15': '2014-15_Kerala'}, inplace=True)

df12= pd.merge(df11,DF_MP,how='inner',on='Item')
df12.rename(columns={'2014-15': '2014-15_MP'}, inplace=True)

df13= pd.merge(df12,DF_Maharashtra,how='inner',on='Item')
df13.rename(columns={'2014-15': '2014-15_Maharashtra'}, inplace=True)

df14= pd.merge(df13,DF_Manipur,how='inner',on='Item')
df14.rename(columns={'2014-15': '2014-15_Manipur'}, inplace=True)

df15= pd.merge(df14,DF_Meghalaya,how='inner',on='Item')
df15.rename(columns={'2014-15': '2014-15_Meghalaya'}, inplace=True)

df16= pd.merge(df15,DF_Mizoram,how='inner',on='Item')
df16.rename(columns={'2014-15': '2014-15_Mizoram'}, inplace=True)

df17= pd.merge(df16,DF_Nagaland,how='inner',on='Item')
df17.rename(columns={'2014-15': '2014-15_Nagaland'}, inplace=True)

df18= pd.merge(df17,DF_Odisha,how='inner',on='Item')
df18.rename(columns={'2014-15': '2014-15_Odisha'}, inplace=True)

df19= pd.merge(df18,DF_Punjab,how='inner',on='Item')
df19.rename(columns={'2014-15': '2014-15_Punjab'}, inplace=True)

df20= pd.merge(df19,DF_Rajasthan,how='inner',on='Item')
df20.rename(columns={'2014-15': '2014-15_Rajasthan'}, inplace=True)

df21= pd.merge(df20,DF_Sikkim,how='inner',on='Item')
df21.rename(columns={'2014-15': '2014-15_Sikkim'}, inplace=True)

df22= pd.merge(df21,DF_TN,how='inner',on='Item')
df22.rename(columns={'2014-15': '2014-15_TN'}, inplace=True)

df23= pd.merge(df22,DF_Telangana,how='inner',on='Item')
df23.rename(columns={'2014-15': '2014-15_Telangana'}, inplace=True)

df24= pd.merge(df23,DF_Tripura,how='inner',on='Item')
df24.rename(columns={'2014-15': '2014-15_Tripura'}, inplace=True)

df25= pd.merge(df24,DF_UP,how='inner',on='Item')
df25.rename(columns={'2014-15': '2014-15_UP'}, inplace=True)

df26= pd.merge(df25,DF_Uttarakhand,how='inner',on='Item')
df26.rename(columns={'2014-15': '2014-15_Uttarakhand'}, inplace=True)
df26
# Out:
#     S.No.                                               Item  2014-15_Andhra  \
# 0       1                  Agriculture, forestry and fishing        14819416
# 1     1.1                                              Crops         7893514
# 2     1.2                                          Livestock         4309078
# 3     1.3                               Forestry and logging          346160
# 4     1.4                            Fishing and aquaculture         2270664
# 5       2                               Mining and quarrying         1484300
# 6   Total                                            Primary        16303716
# 7       3                                      Manufacturing         4672266
# 8       4  Electricity, gas, water supply & other utility...         1151729
# 9       5                                       Construction         4664889
# 10  Total                                          Secondary        10488884
# ...

# %%
df27=df26.iloc[29:,1:]

# %%
df27
# Out:
#                      Item  2014-15_Andhra  2014-15_Arunachal  2014-15_Assam  \
# 29  Per Capita GSDP (Rs.)          104977             112718          60621
#
#     2014-15_Bihar  2014-15_Chhattisgarh  2014-15_Goa  2014-15_Gujarat  \
# 29          33954                 86860       271793         141263.0
#
#     2014-15_Haryana  2014-15_HP         ...           2014-15_Nagaland  \
# 29         164077.0      147330         ...                      89607
#
#     2014-15_Odisha  2014-15_Punjab  2014-15_Rajasthan  2014-15_Sikkim  \
# 29           73979          126606              84837          240274
#
#     2014-15_TN  2014-15_Telangana  2014-15_Tripura  2014-15_UP  \
# 29      146503             139035          77358.0       49450
#
#     2014-15_Uttarakhand
# 29             153076.0
#
# [1 rows x 28 columns]

# %%
df27.set_index('Item',inplace=True)

# %%
df27.transpose().sort_values('Per Capita GSDP (Rs.)').plot(kind='bar',title='GDP per capita for all the states',figsize=(10,5))

# %%
TopGDP5=df27.transpose().sort_values('Per Capita GSDP (Rs.)',ascending=False).iloc[:5,:]
TopGDP5
# Out:
# Item                 Per Capita GSDP (Rs.)
# 2014-15_Goa                       271793.0
# 2014-15_Sikkim                    240274.0
# 2014-15_Haryana                   164077.0
# 2014-15_Kerala                    154778.0
# 2014-15_Uttarakhand               153076.0

# %%
BottomGDP5=df27.transpose().sort_values('Per Capita GSDP (Rs.)',ascending=True).iloc[:5,:]
BottomGDP5
# Out:
# Item               Per Capita GSDP (Rs.)
# 2014-15_Bihar                    33954.0
# 2014-15_UP                       49450.0
# 2014-15_Manipur                  58442.0
# 2014-15_Assam                    60621.0
# 2014-15_Jharkhand                62091.0

# %%
df28=df27.transpose()
df28
Ratio=df28.max()/df28.min()
Ratio
# Out:
# Item
# Per Capita GSDP (Rs.)    8.004742
# dtype: float64

# %%
df29=df26.loc[(df26.Item=='Primary')|  (df26.Item=='Secondary') | (df26.Item=='Tertiary')| (df26.Item =='TOTAL GSVA at basic prices')]

# %%
df30=df29.set_index('Item').transpose()
df30
# Out:
# Item                      Primary    Secondary     Tertiary  \
# S.No.                       Total        Total        Total
# 2014-15_Andhra           16303716     10488884     22032942
# 2014-15_Arunachal          716959       287489       631844
# 2014-15_Assam             5326697      4033091      9307109
# 2014-15_Bihar             8019997      5984896     22179969
# 2014-15_Chhattisgarh      6400817      8238886      7588778
# 2014-15_Goa                312129      1547536      1738217
# 2014-15_Gujarat       1.58872e+07  3.30235e+07  3.02204e+07
# 2014-15_Haryana       8.04042e+06  1.25614e+07  1.92266e+07
# 2014-15_HP                1548366      4119162      4133326
# 2014-15_Jharkhand         5248354      6241471      8133341
# 2014-15_Karnataka        12066304     20484404     50490630
# 2014-15_Kerala            6489442     12070040     29673778
# 2014-15_MP               17854020     10044889     18117360
# 2014-15_Maharashtra      21758383     47445207     88631076
# ...

# %%
df30.drop('S.No.',axis=0,inplace=True)

# %%
df30['Primary_Share']=df30.apply(lambda x: (x['Primary'] /  x['TOTAL GSVA at basic prices'])*100, axis=1)
df30['Secondary_Share']=df30.apply(lambda x: (x['Secondary'] /  x['TOTAL GSVA at basic prices'])*100, axis=1)
df30['Tertiary_Share']=df30.apply(lambda x: (x['Tertiary'] /  x['TOTAL GSVA at basic prices'])*100, axis=1)
df30
# Out:
# Item                      Primary    Secondary     Tertiary  \
# 2014-15_Andhra           16303716     10488884     22032942
# 2014-15_Arunachal          716959       287489       631844
# 2014-15_Assam             5326697      4033091      9307109
# 2014-15_Bihar             8019997      5984896     22179969
# 2014-15_Chhattisgarh      6400817      8238886      7588778
# 2014-15_Goa                312129      1547536      1738217
# 2014-15_Gujarat       1.58872e+07  3.30235e+07  3.02204e+07
# 2014-15_Haryana       8.04042e+06  1.25614e+07  1.92266e+07
# 2014-15_HP                1548366      4119162      4133326
# 2014-15_Jharkhand         5248354      6241471      8133341
# 2014-15_Karnataka        12066304     20484404     50490630
# 2014-15_Kerala            6489442     12070040     29673778
# 2014-15_MP               17854020     10044889     18117360
# 2014-15_Maharashtra      21758383     47445207     88631076
# 2014-15_Manipur            383140       220173  1.17733e+06
# ...

# %%
df30.iloc[:,4:].plot(kind='bar',figsize=(16,5),title='State wise percentage contribution of primary, secondary and tertiary sectors')

# %%
#df27=df27.sort_values(by='Per Capita GSDP (Rs.)',ascending=True)#.reset_index()  # need to uncomment 
#df27['Category']=df27.apply(lambda x: (x['Primary'] /  x['TOTAL GSVA at basic prices'])*100, axis=1)

# %%
#df27['Category']=df27.apply(lambda x: 'C1' if x['Per Capita GSDP (Rs.)'] > 154778.0 else 'C2' , axis=1)
#df27['Category']=df27.apply(lambda x: 'C4' if df27['Per Capita GSDP (Rs.)'] < df27['Per Capita GSDP (Rs.)'].quantile(.20)] else 'NA' , axis=1)
# 
#x = lambda a : a + 10

#df30['Primary_Share']=df30.apply(lambda x: (x['Primary'] /  x['TOTAL GSVA at basic prices'])*100, axis=1)
#df27

# %%
df_quant=df27.quantile([0.20,0.5, 0.85, 1], axis = 0)
df_quant
# Out:
#       2014-15_Andhra  2014-15_Arunachal  2014-15_Assam  2014-15_Bihar  \
# 0.20        104977.0           112718.0        60621.0        33954.0
# 0.50        104977.0           112718.0        60621.0        33954.0
# 0.85        104977.0           112718.0        60621.0        33954.0
# 1.00        104977.0           112718.0        60621.0        33954.0
#
#       2014-15_Chhattisgarh  2014-15_Goa  2014-15_Gujarat  2014-15_Haryana  \
# 0.20               86860.0     271793.0         141263.0         164077.0
# 0.50               86860.0     271793.0         141263.0         164077.0
# 0.85               86860.0     271793.0         141263.0         164077.0
# 1.00               86860.0     271793.0         141263.0         164077.0
#
#       2014-15_HP  2014-15_Jharkhand         ...           2014-15_Nagaland  \
# 0.20    147330.0            62091.0         ...                    89607.0
# 0.50    147330.0            62091.0         ...                    89607.0
# ...

# %%
df26.drop('S.No.',axis=1,inplace=True)

# %%
df26f=df26.set_index('Item').transpose().apply(pd.to_numeric)

# %%
df26f.dtypes.head()
# Out:
# Item
# Agriculture, forestry and fishing    float64
# Crops                                float64
# Livestock                            float64
# Forestry and logging                 float64
# Fishing and aquaculture              float64
# dtype: object

# %%
df26f['Category']=df26f.apply(lambda x:'C1' if x['Per Capita GSDP (Rs.)'] >= df26f['Per Capita GSDP (Rs.)'].quantile(.85)  else ('C2' if x['Per Capita GSDP (Rs.)']  >= df26f['Per Capita GSDP (Rs.)'].quantile(.5) else  ('C3' if x['Per Capita GSDP (Rs.)']  >= df26f['Per Capita GSDP (Rs.)'].quantile(.20) else  'C4')) , axis=1)

# %%
df26f.head()
# Out:
# Item                  Agriculture, forestry and fishing      Crops  Livestock  \
# 2014-15_Andhra                               14819416.0  7893514.0  4309078.0
# 2014-15_Arunachal                              686117.0   415520.0    38387.0
# 2014-15_Assam                                 3855548.0  2890544.0   173478.0
# 2014-15_Bihar                                 7951890.0  4688237.0  2060296.0
# 2014-15_Chhattisgarh                          3948847.0  2613371.0   352208.0
#
# Item                  Forestry and logging  Fishing and aquaculture  \
# 2014-15_Andhra                    346160.0                2270664.0
# 2014-15_Arunachal                 224017.0                   8193.0
# 2014-15_Assam                     261987.0                 529539.0
# 2014-15_Bihar                     550132.0                 653224.0
# 2014-15_Chhattisgarh              597785.0                 385483.0
#
# Item                  Mining and quarrying     Primary  Manufacturing  \
# ...

# %%
#dfpp=df26.set_index('Item').transpose()  # dfpp is now same as df26f only for ref . dont run

# %%
#dfpp.drop('S.No.',axis=0,inplace=True)

# %%
#can be deleted later if not needed
#dfpp['Category']=dfpp.apply(lambda x:'C1' if x['Per Capita GSDP (Rs.)'] >= dfpp['Per Capita GSDP (Rs.)'].quantile(.85)  else ('C2' if x['Per Capita GSDP (Rs.)']  >= dfpp['Per Capita GSDP (Rs.)'].quantile(.5) else  ('C3' if x['Per Capita GSDP (Rs.)']  >= dfpp['Per Capita GSDP (Rs.)'].quantile(.20) else  'C4')) , axis=1)

# %%
#dfpp.dtypes #needed

# %%
#dfpp.Primary=pd.to_numeric(dfpp.Primary) #needed

# %%
#dfpp = dfpp.apply(pd.to_numeric)  # needed

# %%
#dfpp  # not required

# %%
#border

# %%
df26ff=df26f.groupby('Category').sum()

# %%
df26ff
# Out:
# Item      Agriculture, forestry and fishing       Crops   Livestock  \
# Category
# C1                               14391809.0   7962514.0   4619756.0
# C2                               90028438.0  55443609.0  23672969.0
# C3                               27407472.0  15782803.0   6826716.0
# C4                               56735044.0  39331055.0  11901405.0
#
# Item      Forestry and logging  Fishing and aquaculture  Mining and quarrying  \
# Category
# C1                    872335.0                 937204.0              588961.0
# C2                   5949373.0                4962486.0            11857646.0
# C3                   3699735.0                1098217.0             9351471.0
# C4                   3673623.0                1828960.0             6096419.0
#
# Item          Primary  Manufacturing  \
# Category
# C1         14980771.0     13758793.0
# C2        101886085.0    113868796.0
# C3         36758945.0     17366065.0
# C4         62831463.0     24987032.0
#
# ...

# %%
df26ff['80_Cont_GSDP']=df26ff.apply(lambda x: x['Gross State Domestic Product'] *  0.8, axis=1)

# %%
df26ff
# Out:
# Item      Agriculture, forestry and fishing       Crops   Livestock  \
# Category
# C1                               14391809.0   7962514.0   4619756.0
# C2                               90028438.0  55443609.0  23672969.0
# C3                               27407472.0  15782803.0   6826716.0
# C4                               56735044.0  39331055.0  11901405.0
#
# Item      Forestry and logging  Fishing and aquaculture  Mining and quarrying  \
# Category
# C1                    872335.0                 937204.0              588961.0
# C2                   5949373.0                4962486.0            11857646.0
# C3                   3699735.0                1098217.0             9351471.0
# C4                   3673623.0                1828960.0             6096419.0
#
# Item          Primary  Manufacturing  \
# Category
# C1         14980771.0     13758793.0
# C2        101886085.0    113868796.0
# C3         36758945.0     17366065.0
# C4         62831463.0     24987032.0
#
# ...

# %%
df26ff=df26ff.transpose()

# %%
#drop rows pri, sec, tt
df26ff  #.loc()
# Out:
# Category                                                     C1            C2  \
# Item
# Agriculture, forestry and fishing                    14391809.0  9.002844e+07
# Crops                                                 7962514.0  5.544361e+07
# Livestock                                             4619756.0  2.367297e+07
# Forestry and logging                                   872335.0  5.949373e+06
# Fishing and aquaculture                                937204.0  4.962486e+06
# Mining and quarrying                                   588961.0  1.185765e+07
# Primary                                              14980771.0  1.018861e+08
# Manufacturing                                        13758793.0  1.138688e+08
# Electricity, gas, water supply & other utility ...    2000998.0  1.497511e+07
# Construction                                         11264451.0  4.531845e+07
# Secondary                                            27024240.0  1.741624e+08
# ...

# %%
#5-5-2019

# %%
df26f3=df26ff.iloc[:-1,:]

# %%
df26f3.drop(['Primary','Secondary','Tertiary'],axis=0,inplace=True)

# %%
df26f3
# Out:
# Category                                                     C1            C2  \
# Item
# Agriculture, forestry and fishing                    14391809.0  9.002844e+07
# Crops                                                 7962514.0  5.544361e+07
# Livestock                                             4619756.0  2.367297e+07
# Forestry and logging                                   872335.0  5.949373e+06
# Fishing and aquaculture                                937204.0  4.962486e+06
# Mining and quarrying                                   588961.0  1.185765e+07
# Manufacturing                                        13758793.0  1.138688e+08
# Electricity, gas, water supply & other utility ...    2000998.0  1.497511e+07
# Construction                                         11264451.0  4.531845e+07
# Trade, repair, hotels and restaurants                13995159.0  6.547226e+07
# Hotels & restaurants                                  1005412.0  6.503926e+06
# ...

# %%
df26f3.loc['Gross State Domestic Product','C1']
# Out:
# 101930677.0

# %%
df26f3.C1=df26f3.C1.apply(lambda x: x/df26f3.loc['Gross State Domestic Product','C1']*100)

# %%
df26f3.head()
# Out:
# Category                                  C1          C2          C3  \
# Item
# Agriculture, forestry and fishing  14.119213  90028438.0  27407472.0
# Crops                               7.811695  55443609.0  15782803.0
# Livestock                           4.532253  23672969.0   6826716.0
# Forestry and logging                0.855812   5949373.0   3699735.0
# Fishing and aquaculture             0.919452   4962486.0   1098217.0
#
# Category                                   C4
# Item
# Agriculture, forestry and fishing  56735044.0
# Crops                              39331055.0
# Livestock                          11901405.0
# Forestry and logging                3673623.0
# Fishing and aquaculture             1828960.0

# %%
df26f3.loc['Gross State Domestic Product','C2']
# Out:
# 639027294.0

# %%
df26f3.C2=df26f3.C2.apply(lambda x: (x/df26f3.loc['Gross State Domestic Product','C2'])*100)

# %%
df26f3
# Out:
# Category                                                    C1          C2  \
# Item
# Agriculture, forestry and fishing                    14.119213   14.088356
# Crops                                                 7.811695    8.676251
# Livestock                                             4.532253    3.704532
# Forestry and logging                                  0.855812    0.931005
# Fishing and aquaculture                               0.919452    0.776569
# Mining and quarrying                                  0.577805    1.855577
# Manufacturing                                        13.498187   17.819082
# Electricity, gas, water supply & other utility ...    1.963097    2.343422
# Construction                                         11.051090    7.091786
# Trade, repair, hotels and restaurants                13.730076   10.245613
# Hotels & restaurants                                  0.986368    1.017785
# ...

# %%
df26f3.loc['Gross State Domestic Product','C3']
df26f3.C3=df26f3.C3.apply(lambda x: (x/df26f3.loc['Gross State Domestic Product','C3'])*100)

# %%
df26f3.loc['Gross State Domestic Product','C4']
# Out:
# 233252066.0

# %%
df26f3.C4=df26f3.C4.apply(lambda x: (x/df26f3.loc['Gross State Domestic Product','C4'])*100)

# %%
df26f4=df26f3.transpose()

# %%
#Summarised data for sub sectors which contribute to the GSDP of each category (in percentage)
df26f4.iloc[:,:-6].transpose()
# Out:
# Category                                                   C1         C2  \
# Item
# Agriculture, forestry and fishing                   14.119213  14.088356
# Crops                                                7.811695   8.676251
# Livestock                                            4.532253   3.704532
# Forestry and logging                                 0.855812   0.931005
# Fishing and aquaculture                              0.919452   0.776569
# Mining and quarrying                                 0.577805   1.855577
# Manufacturing                                       13.498187  17.819082
# Electricity, gas, water supply & other utility ...   1.963097   2.343422
# Construction                                        11.051090   7.091786
# Trade, repair, hotels and restaurants               13.730076  10.245613
# Hotels & restaurants                                 0.986368   1.017785
# Transport, storage, communication & services re...   6.689409   6.075921
# ...

# %%
df26f4.iloc[:,:-6].plot(kind='bar',stacked=True,figsize=(20,5),sort_columns =True)  #iloc[:,:-6]

# %%
#data 2  assignment

# %%
df26.head()
# Out:
#                                 Item  2014-15_Andhra  2014-15_Arunachal  \
# 0  Agriculture, forestry and fishing        14819416             686117
# 1                              Crops         7893514             415520
# 2                          Livestock         4309078              38387
# 3               Forestry and logging          346160             224017
# 4            Fishing and aquaculture         2270664               8193
#
#    2014-15_Assam  2014-15_Bihar  2014-15_Chhattisgarh  2014-15_Goa  \
# 0        3855548        7951890               3948847       308507
# 1        2890544        4688237               2613371       140421
# 2         173478        2060296                352208        30141
# 3         261987         550132                597785        15744
# 4         529539         653224                385483       122201
#
#    2014-15_Gujarat  2014-15_Haryana  2014-15_HP         ...           \
# ...

# %%
dff1=df26.iloc[-1:]

# %%
dff1
# Out:
#                      Item  2014-15_Andhra  2014-15_Arunachal  2014-15_Assam  \
# 29  Per Capita GSDP (Rs.)          104977             112718          60621
#
#     2014-15_Bihar  2014-15_Chhattisgarh  2014-15_Goa  2014-15_Gujarat  \
# 29          33954                 86860       271793         141263.0
#
#     2014-15_Haryana  2014-15_HP         ...           2014-15_Nagaland  \
# 29         164077.0      147330         ...                      89607
#
#     2014-15_Odisha  2014-15_Punjab  2014-15_Rajasthan  2014-15_Sikkim  \
# 29           73979          126606              84837          240274
#
#     2014-15_TN  2014-15_Telangana  2014-15_Tripura  2014-15_UP  \
# 29      146503             139035          77358.0       49450
#
#     2014-15_Uttarakhand
# 29             153076.0
#
# [1 rows x 28 columns]

# %%
vlst=[]

for i in dff1.columns:
    vlst.append(i.replace('2014-15_',''))

dff1.columns=vlst

# %%
dff1
# Out:
#                      Item  Andhra  Arunachal  Assam  Bihar  Chhattisgarh  \
# 29  Per Capita GSDP (Rs.)  104977     112718  60621  33954         86860
#
#        Goa   Gujarat   Haryana      HP     ...       Nagaland  Odisha  Punjab  \
# 29  271793  141263.0  164077.0  147330     ...          89607   73979  126606
#
#     Rajasthan  Sikkim      TN  Telangana  Tripura     UP  Uttarakhand
# 29      84837  240274  146503     139035  77358.0  49450     153076.0
#
# [1 rows x 28 columns]

# %%
#dff1.drop('Duration', axis=1,inplace=True)

# %%
dff1.set_index('Item', inplace=True)

# %%
dff1
# Out:
#                        Andhra  Arunachal  Assam  Bihar  Chhattisgarh     Goa  \
# Item
# Per Capita GSDP (Rs.)  104977     112718  60621  33954         86860  271793
#
#                         Gujarat   Haryana      HP  Jharkhand     ...       \
# Item                                                             ...
# Per Capita GSDP (Rs.)  141263.0  164077.0  147330      62091     ...
#
#                        Nagaland  Odisha  Punjab  Rajasthan  Sikkim      TN  \
# Item
# Per Capita GSDP (Rs.)     89607   73979  126606      84837  240274  146503
#
#                        Telangana  Tripura     UP  Uttarakhand
# Item
# Per Capita GSDP (Rs.)     139035  77358.0  49450     153076.0
#
# [1 rows x 27 columns]

# %%
#dff1.drop('All_India GDP',axis=1,inplace=True)

# %%
dff1=dff1.transpose()

# %%
dff1
# Out:
# Item          Per Capita GSDP (Rs.)
# Andhra                     104977.0
# Arunachal                  112718.0
# Assam                       60621.0
# Bihar                       33954.0
# Chhattisgarh                86860.0
# Goa                        271793.0
# Gujarat                    141263.0
# Haryana                    164077.0
# HP                         147330.0
# Jharkhand                   62091.0
# Karnataka                  145141.0
# Kerala                     154778.0
# MP                          62989.0
# Maharashtra                152853.0
# Manipur                     58442.0
# Meghalaya                   76228.0
# Mizoram                     97687.0
# Nagaland                    89607.0
# Odisha                      73979.0
# Punjab                     126606.0
# Rajasthan                   84837.0
# Sikkim                     240274.0
# TN                         146503.0
# Telangana                  139035.0
# Tripura                     77358.0
# ...

# %%
import numpy as np

# %%
dff1.dtypes
# Out:
# Item
# Per Capita GSDP (Rs.)    float64
# dtype: object

# %%
#dff1['GSDP - CURRENT PRICES (` in Crore)']=dff1['GSDP - CURRENT PRICES (` in Crore)'].astype(int)
#pd.to_numeric(dff1['GSDP - CURRENT PRICES (` in Crore)']) 
#dfpp = dfpp.apply(pd.to_numeric)

# %%
dff1=dff1.rename(index={'Andhra':'Andhra Pradesh','Arunachal':'Arunachal Pradesh','Chhattisgarh':'Chhatisgarh','HP':'Himachal Pradesh','MP':'Madhya Pradesh','TN':'Tamil Nadu','UP':'Uttar Pradesh','Uttarakhand':'Uttrakhand'})

# %%
dff1
# Out:
# Item               Per Capita GSDP (Rs.)
# Andhra Pradesh                  104977.0
# Arunachal Pradesh               112718.0
# Assam                            60621.0
# Bihar                            33954.0
# Chhatisgarh                      86860.0
# Goa                             271793.0
# Gujarat                         141263.0
# Haryana                         164077.0
# Himachal Pradesh                147330.0
# Jharkhand                        62091.0
# Karnataka                       145141.0
# Kerala                          154778.0
# Madhya Pradesh                   62989.0
# Maharashtra                     152853.0
# Manipur                          58442.0
# Meghalaya                        76228.0
# Mizoram                          97687.0
# Nagaland                         89607.0
# Odisha                           73979.0
# Punjab                          126606.0
# Rajasthan                        84837.0
# Sikkim                          240274.0
# ...

# %%
dff2=pd.read_csv(r'C:\Users\Vaibhav\Desktop\GDP\Data2.csv')

# %%
dff2.tail()#.iloc[:,2:4]
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 32         33                    Tripura                 2.22
# 33         34              Uttar Pradesh                10.28
# 34         35                 Uttrakhand                 1.16
# 35         36                West Bengal                 6.30
# 36  All India                  All India                 4.67
#
#     Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 32                 3.58                   1.28                       3.08
# 33                 7.08                   8.58                       1.06
# 34                 3.07                   4.04                       0.13
# 35                 2.91                   1.47                       5.18
# 36                 4.34                   4.13                       3.13
#
#     Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 32                       2.72                       1.99
# ...

# %%
dff2.drop('Primary - 2014-2015.1',axis=1,inplace=True)

# %%
dff2.drop(36,axis=0,inplace=True)

# %%
dff2
# Out:
#    Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0        1              A & N Islands                 0.68
# 1        2             Andhra Pradesh                 3.18
# 2        3          Arunachal Pradesh                15.16
# 3        4                      Assam                 6.24
# 4        5                      Bihar                  NaN
# 5        6                 Chandigarh                  NaN
# 6        7                Chhatisgarh                 4.14
# 7        8       Dadra & Nagar Haveli                  NaN
# 8        9                Daman & Diu                  NaN
# 9       10                      Delhi                  NaN
# 10      11                        Goa                  NaN
# 11      12                    Gujarat                 0.74
# 12      13                    Haryana                 1.29
# 13      14           Himachal Pradesh                 0.45
# 14      15          Jammu and Kashmir                 6.30
# ...

# %%
dff2.set_index('Level of Education - State',inplace=True)

# %%
mlst=[]
for i in dff2.columns:
     if '2014-2015' in i :
            if 'Senior' not in i:
                mlst.append(i)

# %%
mlst
# Out:
# ['Primary - 2014-2015', 'Upper Primary - 2014-2015', 'Secondary - 2014-2015']

# %%
dff2=dff2[mlst]

# %%
dff2
# Out:
#                             Primary - 2014-2015  Upper Primary - 2014-2015  \
# Level of Education - State
# A & N Islands                              1.21                       1.69
# Andhra Pradesh                             4.35                       5.20
# Arunachal Pradesh                         10.89                       6.71
# Assam                                      7.44                      10.51
# Bihar                                      2.09                       4.08
# Chandigarh                                  NaN                       0.44
# Chhatisgarh                                1.42                       5.85
# Dadra & Nagar Haveli                       1.57                       4.02
# Daman & Diu                                0.85                       3.11
# Delhi                                       NaN                       0.76
# Goa                                        0.20                       0.07
# ...

# %%
dff2.loc[np.isnan(dff2['Primary - 2014-2015']),['Primary - 2014-2015']] = dff2['Primary - 2014-2015'].mean()
dff2.loc[np.isnan(dff2['Upper Primary - 2014-2015']), ['Upper Primary - 2014-2015']] = dff2['Upper Primary - 2014-2015'].mean()
dff2.loc[np.isnan(dff2['Secondary - 2014-2015']), ['Secondary - 2014-2015']] = dff2['Secondary - 2014-2015'].mean()

#Primary - 2014-2015	Upper Primary - 2014-2015	Secondary - 2014-2015

# %%
dff2
# Out:
#                             Primary - 2014-2015  Upper Primary - 2014-2015  \
# Level of Education - State
# A & N Islands                            1.2100                   1.690000
# Andhra Pradesh                           4.3500                   5.200000
# Arunachal Pradesh                       10.8900                   6.710000
# Assam                                    7.4400                  10.510000
# Bihar                                    2.0900                   4.080000
# Chandigarh                               4.9375                   0.440000
# Chhatisgarh                              1.4200                   5.850000
# Dadra & Nagar Haveli                     1.5700                   4.020000
# Daman & Diu                              0.8500                   3.110000
# Delhi                                    4.9375                   0.760000
# Goa                                      0.2000                   0.070000
# ...

# %%
#dff2=dff2.rename(index={'A & N Islands':'Andaman & Nicobar Islands','Chhatisgarh':'Chhattisgarh','Jammu and Kashmir':'Jammu & Kashmir','Uttrakhand':'Uttarakhand'})
#dff2.rename(index={'Jammu and Kashmir':'Jammu & Kashmir'})
#dff2.rename(index={'Uttrakhand':'Uttarakhand'})
#dff2.rename(index={'West Bengal':'West Bengal'})

# %%
dff2
# Out:
#                             Primary - 2014-2015  Upper Primary - 2014-2015  \
# Level of Education - State
# A & N Islands                            1.2100                   1.690000
# Andhra Pradesh                           4.3500                   5.200000
# Arunachal Pradesh                       10.8900                   6.710000
# Assam                                    7.4400                  10.510000
# Bihar                                    2.0900                   4.080000
# Chandigarh                               4.9375                   0.440000
# Chhatisgarh                              1.4200                   5.850000
# Dadra & Nagar Haveli                     1.5700                   4.020000
# Daman & Diu                              0.8500                   3.110000
# Delhi                                    4.9375                   0.760000
# Goa                                      0.2000                   0.070000
# ...

# %%
#dff2.drop(['Dadra & Nagar Haveli','Daman & Diu','Lakshadweep'],axis=0,inplace=True)
#dff1.drop('States',axis=1,inplace=True)
dff1.head()
# Out:
# Item               Per Capita GSDP (Rs.)
# Andhra Pradesh                  104977.0
# Arunachal Pradesh               112718.0
# Assam                            60621.0
# Bihar                            33954.0
# Chhatisgarh                      86860.0

# %%
dff1.reset_index(inplace=True)

dff1.rename(columns={'index': 'States'}, inplace=True)
dff1
# Out:
# Item             States  Per Capita GSDP (Rs.)
# 0        Andhra Pradesh               104977.0
# 1     Arunachal Pradesh               112718.0
# 2                 Assam                60621.0
# 3                 Bihar                33954.0
# 4           Chhatisgarh                86860.0
# 5                   Goa               271793.0
# 6               Gujarat               141263.0
# 7               Haryana               164077.0
# 8      Himachal Pradesh               147330.0
# 9             Jharkhand                62091.0
# 10            Karnataka               145141.0
# 11               Kerala               154778.0
# 12       Madhya Pradesh                62989.0
# 13          Maharashtra               152853.0
# 14              Manipur                58442.0
# 15            Meghalaya                76228.0
# 16              Mizoram                97687.0
# 17             Nagaland                89607.0
# 18               Odisha                73979.0
# ...

# %%
#dff1.rename(index={'Andhra':'Andhra Pradesh','Arunachal':'Arunachal Pradesh','Chhattisgarh':'Chhatisgarh','HP':'Himachal Pradesh','MP':'Madhya Pradesh','TN':'Tamil Nadu','UP':'Uttar Pradesh','Uttarakhand':'Uttrakhand'})

# %%
dff2.reset_index(inplace=True)

# %%
dff2.head()
# Out:
#   Level of Education - State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0              A & N Islands                 1.21                       1.69
# 1             Andhra Pradesh                 4.35                       5.20
# 2          Arunachal Pradesh                10.89                       6.71
# 3                      Assam                 7.44                      10.51
# 4                      Bihar                 2.09                       4.08
#
#    Secondary - 2014-2015
# 0                   9.87
# 1                  15.71
# 2                  17.11
# 3                  27.06
# 4                  25.90

# %%
dff2.rename(columns={'Level of Education - State':'States'}, inplace=True)

# %%
dff2.head()
# Out:
#               States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      A & N Islands                 1.21                       1.69
# 1     Andhra Pradesh                 4.35                       5.20
# 2  Arunachal Pradesh                10.89                       6.71
# 3              Assam                 7.44                      10.51
# 4              Bihar                 2.09                       4.08
#
#    Secondary - 2014-2015
# 0                   9.87
# 1                  15.71
# 2                  17.11
# 3                  27.06
# 4                  25.90

# %%
dff3 = pd.merge(dff1, dff2, how='inner', on='States')

# %%
dff3
# Out:
#                States  Per Capita GSDP (Rs.)  Primary - 2014-2015  \
# 0      Andhra Pradesh               104977.0               4.3500
# 1   Arunachal Pradesh               112718.0              10.8900
# 2               Assam                60621.0               7.4400
# 3               Bihar                33954.0               2.0900
# 4         Chhatisgarh                86860.0               1.4200
# 5                 Goa               271793.0               0.2000
# 6             Gujarat               141263.0               0.7600
# 7             Haryana               164077.0               0.4100
# 8    Himachal Pradesh               147330.0               0.4600
# 9           Jharkhand                62091.0               6.4100
# 10          Karnataka               145141.0               2.3200
# 11             Kerala               154778.0               4.9375
# 12     Madhya Pradesh                62989.0              10.1400
# ...

# %%
dff3.set_index('States',inplace=True)

# %%
import seaborn as sns
import matplotlib as plt

# %%
corr =dff3.corr()

# %%
corr
# Out:
#                            Per Capita GSDP (Rs.)  Primary - 2014-2015  \
# Per Capita GSDP (Rs.)                   1.000000            -0.454041
# Primary - 2014-2015                    -0.454041             1.000000
# Upper Primary - 2014-2015              -0.542173             0.436040
# Secondary - 2014-2015                  -0.465649             0.129010
#
#                            Upper Primary - 2014-2015  Secondary - 2014-2015
# Per Capita GSDP (Rs.)                      -0.542173              -0.465649
# Primary - 2014-2015                         0.436040               0.129010
# Upper Primary - 2014-2015                   1.000000               0.533824
# Secondary - 2014-2015                       0.533824               1.000000

# %%
sns.heatmap(corr, cmap="YlGnBu", annot=True)
#plt.show()
